# %%
import pickle as pkl

# %%
train_file = './../../data/train_human_generated.pkl'

# %%
train_data = pkl.load(open(train_file, 'rb'))

# %%
train_data

# %%
train_file = './../../data/valid_human_generated.pkl'

# %%
val_data = pkl.load(open(train_file, 'rb'))

# %%
val_data
# Out:
# {'Are you sure you want to permanently delete these files?\n': ['Are you sure you want to permanently hatana chahte he?\n',
#   'Kya aap in files ko want to permanently delete?\n'],
#  'Three public meetings were held in Bombay City to observe this day.\n': ['Three public meetings were held in Bombay City iss avasar par.\n',
#   'Bombay mai teen public meetings ki gayi to observe this day.\n'],
#  'Nominee of the insurance has to be a near relative of the subscriber.\n': ['Nominee of the Bima has to be a nikat sambandhi of the abhidata.\n',
#   'Bima ka nominee subscriber ka near relative hoga.\n',
#   'Bima ka namit vyakti has to be a near relative of the abhidata.\n',
#   'Bima ka nominee abhidata ka nikat relative hoga.\n'],
#  'Thus there was an inadequate appreciation of the necessity for speedy action in a vital sector.\n': ['Is prakar ke vital chhetra me speedy action karne ki necessity par koi dhyan nahi diya gaya\n',
# ...
